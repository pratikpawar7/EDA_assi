# %%
Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
predicting the quality of wine.
Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
Discuss the advantages and disadvantages of different imputation techniques.
Q3. What are the key factors that affect students' performance in exams? How would you go about
analyzing these factors using statistical techniques?
Advantages of Imputation Techniques:
Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
these features to improve normality?
Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
features. What is the minimum number of principal components required to explain 90% of the variance in
the data?

# %%
'''
Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
predicting the quality of wine.
'''

key feature :
    1.It is imbalanced data set . 
    2.min citric acid can be 0 also . 
    3.

# %%
'''
Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
Discuss the advantages and disadvantages of different imputation techniques.
'''
There is no missing values in the wine dataset . 

and if there is any missing value in the dataset then we drop this row . 


Advantages of Imputation Techniques:

Maintains Dataset Size:     Imputation retains the full dataset, preserving valuable information
                            and statistical power.
Improves Model Performance: By filling in missing values, models can train on complete data, 
                            enhancing accuracy and reliability.
Reduces Bias:               Proper imputation can mitigate biases that result from missing data.



Disadvantages of Imputation Techniques:

Introduces Uncertainty:     Imputed values may not accurately reflect true values, 
                            introducing uncertainty.
Complexity and Computation: Some advanced imputation methods can be computationally intensive 
                            and complex to implement.
Potential for Overfitting:  Imputation can sometimes lead to overfitting, especially if the 
                            imputed values are not representative of the actual data distribution.

# %%
'''
Q3. What are the key factors that affect students' performance in exams? How would you go about
analyzing these factors using statistical techniques?
'''
key Feature :
    1.standard lunch help student to well perform in exam.
    2.Parents who assosiation degree or masters degree their male child can score good marks in the exam . 
    3.Students of Group A and Group B are perform poor in exam .
    4.Students of Group A and Group B are perform poor in exam  irrespective they are male or female . 
    
    i analyse this factor from the dataset using visuals and graphical representation .

# %%
'''
Q4. Describe the process of feature engineering in the context of the student performance data set. How
did you select and transform the variables for your model?
'''

Feature Engineering involves creating , selecting and transforming the variable to improve model accuracy . 

here the steps : 
    1.Check the missing values in the dataset . 
    2. check the duplicates in the dataset.
    3.Check the data type of the dataset. 
    4. Check the no of unique column of each column . 
    5. check the statistic of the dataset. 
    
steps of feature engineering for transform the variable.  
1.Understand the Data:

2.Handle Missing Values:

3.Create New Features:

4.Transform Existing Features:

5.Feature Selection:

6.Interaction Features:

# %%
'''
Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
features. What is the minimum number of principal components required to explain 90% of the variance in
the data?
'''
# sorry sir i don't understand question so i get help of the chatGPT . but then i understand the code and then write . 

import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

data = pd.read_csv('winequality-red.csv')

# Standardize the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Perform PCA
pca = PCA()
pca.fit(data_scaled)

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance_ratio)

# Plot cumulative explained variance
plt.figure(figsize=(10, 6))
plt.plot(cumulative_explained_variance, marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance vs. Number of Principal Components')
plt.grid(True)
plt.axhline(y=0.90, color='r', linestyle='--')
plt.show()

# Determine the minimum number of components to explain 90% variance
num_components = np.argmax(cumulative_explained_variance >= 0.90) + 1
print(f'Minimum number of principal components to explain 90% variance: {num_components}')
# Out:
# Minimum number of principal components to explain 90% variance: 8

# %%
'''
Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
these features to improve normality?
'''

Load the Dataset:

Import necessary libraries and load the wine quality dataset.

Explore the Dataset:

Check for missing values:
                           Get basic statistics of each feature.
Visualize the Distribution:
                            Plot histograms and box plots for each feature to understand their distributions.
Identify Non-Normal Features:
                            Use visual inspection and statistical tests (e.g., Shapiro-Wilk test) 
                            to identify non-normal features.
Apply Transformations:
                        Apply transformations such as log, square root, or Box-Cox to improve
                        normality of non-normal features.
